# %%
#importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing data

df = pd.read_csv('time_series_covid_19_confirmed.csv')
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...    3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0        0   ...         40       74       84       94
# 1        0        0        0   ...        104      123      146      174
# 2        0        0        0   ...        230      264      302      367
# 3        0        0        0   ...        133      164      188      224
# 4        0        0        0   ...          3        3        3        4
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20
# ...

# %%
df.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  256.000000  256.000000  256.000000  256.000000  256.000000  256.000000
# mean    21.823943   23.158832    2.167969    2.554688    3.675781    5.601562
# std     24.484347   71.120822   27.805753   27.905108   34.737565   48.343840
# min    -41.454500 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      7.844875  -16.237775    0.000000    0.000000    0.000000    0.000000
# 50%     23.692500   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     41.227200   84.497525    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20      ...        \
# count   256.000000   256.000000   256.000000   256.000000      ...
# mean      8.273438    11.433594    21.789062    24.085938      ...
# ...

# %%
df['Province/State'].isnull().sum()
# Out:
# 177

# %% [markdown]
# # Creating a bar chart race animation

# %% [markdown]
# With 177 missing rows it's not a good idea to keep the Province/State column in the data.
#
# Also latitude and longitude will not be necessary for creating a bar chart race animation.

# %%
chart_df = df.drop(['Province/State','Lat', 'Long'],axis=1)
chart_df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20   ...    3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0        0   ...         40       74       84       94
# 1        0        0        0   ...        104      123      146      174
# 2        0        0        0   ...        230      264      302      367
# 3        0        0        0   ...        133      164      188      224
# 4        0        0        0   ...          3        3        3        4
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20
# ...

# %%
chart_df.shape
# Out:
# (256, 72)

# %% [markdown]
# Let's rename the Country/Region column as Country for our future use

# %%
chart_df.rename(columns = {'Country/Region':'Country'},inplace=True)

# %%
chart_df.columns
# Out:
# Index(['Country', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20',
#        '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20',
#        '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20',
#        '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20',
#        '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20',
#        '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20',
#        '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20',
#        '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20',
#        '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20',
#        '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20',
#        '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20',
#        '3/30/20', '3/31/20', '4/1/20'],
#       dtype='object')

# %% [markdown]
# Let's check the number of countries affected by Covid 19

# %%
chart_df['Country'].value_counts()
# Out:
# China                     33
# Canada                    15
# France                    10
# United Kingdom            10
# Australia                  8
# Netherlands                4
# Denmark                    3
# Italy                      1
# Serbia                     1
# Benin                      1
# San Marino                 1
# Switzerland                1
# Norway                     1
# Cyprus                     1
# Rwanda                     1
# Czechia                    1
# Madagascar                 1
# Grenada                    1
# Holy See                   1
# Papua New Guinea           1
# India                      1
# El Salvador                1
# Djibouti                   1
# Cabo Verde                 1
# Slovenia                   1
# Ghana                      1
# Bulgaria                   1
# Morocco                    1
# Ukraine                    1
# Mauritania                 1
#                           ..
# Liechtenstein              1
# ...

# %% [markdown]
# So the number of affected countries seem to be 180 but there are 256 columns. So it is very correct to assume that some countries are repeated.
#
# Well thinking more it will be clear that the repetition maybe due to the Provine/State values because more than one provine may belong to the same country
#
# Since all the province belong to the same country it will be safe to get the sum of number of confirmed cases for all the repititive values in Country name.

# %%
chart_df.head(10)
# Out:
#                Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
# 6            Argentina        0        0        0        0        0        0
# 7              Armenia        0        0        0        0        0        0
# 8            Australia        0        0        0        0        0        0
# 9            Australia        0        0        0        0        3        4
#
#    1/28/20  1/29/20  1/30/20   ...    3/23/20  3/24/20  3/25/20  3/26/20  \
# ...

# %%
chart_df = chart_df.groupby('Country').agg(np.sum)
chart_df = chart_df.reset_index().rename(columns = {'index':'Country'})
chart_df.head(10)
# Out:
#                Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
# 6            Argentina        0        0        0        0        0        0
# 7              Armenia        0        0        0        0        0        0
# 8            Australia        0        0        0        0        4        5
# 9              Austria        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20   ...    3/23/20  3/24/20  3/25/20  3/26/20  \
# ...

# %%
chart_df.shape
# Out:
# (180, 72)

# %% [markdown]
# Now the data looks ready for creating a bar chart race

# %%
#creating the csv file

chart_df.to_csv('bar_chart_race.csv')
